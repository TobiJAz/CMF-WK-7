# %% [markdown]
# # HEADING FOR COMMENTS

# %% [markdown]
# XYZZZZZ

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib as mpl

# %%
initial_data = yf.download("AAPL AMZN FB GOOG MSFT TSLA SPY ^VIX", start="2020-11-08", end="2021-11-08")
# Out:
# [*********************100%***********************]  8 of 8 completed

# %%
initial_data.head()
# Out:
#              Adj Close                                                    \
#                   AAPL         AMZN          FB         GOOG        MSFT
# Date
# 2020-11-09  115.607307  3143.739990  278.769989  1763.000000  216.404266
# 2020-11-10  115.259445  3035.020020  272.429993  1740.390015  209.091370
# 2020-11-11  118.757874  3137.389893  276.480011  1752.709961  214.581009
# 2020-11-12  118.479607  3110.280029  275.079987  1749.839966  213.481110
# 2020-11-13  118.529297  3128.810059  276.950012  1777.020020  214.541367
#
#                                                     Close               ...  \
#                    SPY        TSLA       ^VIX        AAPL         AMZN  ...
# Date                                                                    ...
# 2020-11-09  349.634827  421.260010  25.750000  116.320000  3143.739990  ...
# 2020-11-10  349.122101  410.359985  24.799999  115.970001  3035.020020  ...
# ...

# %%
initial_data['Adj Close'].head()
# Out:
#                   AAPL         AMZN          FB         GOOG        MSFT  \
# Date
# 2020-11-09  115.607307  3143.739990  278.769989  1763.000000  216.404266
# 2020-11-10  115.259445  3035.020020  272.429993  1740.390015  209.091370
# 2020-11-11  118.757874  3137.389893  276.480011  1752.709961  214.581009
# 2020-11-12  118.479607  3110.280029  275.079987  1749.839966  213.481110
# 2020-11-13  118.529297  3128.810059  276.950012  1777.020020  214.541367
#
#                    SPY        TSLA       ^VIX
# Date
# 2020-11-09  349.634827  421.260010  25.750000
# 2020-11-10  349.122101  410.359985  24.799999
# 2020-11-11  351.715546  417.130005  23.450001
# 2020-11-12  348.303589  411.760010  25.350000
# 2020-11-13  353.125702  408.500000  23.100000

# %%
data =  initial_data['Adj Close']
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2020-11-09 to 2021-11-05
# Data columns (total 8 columns):
# AAPL    251 non-null float64
# AMZN    251 non-null float64
# FB      251 non-null float64
# GOOG    251 non-null float64
# MSFT    251 non-null float64
# SPY     251 non-null float64
# TSLA    251 non-null float64
# ^VIX    251 non-null float64
# dtypes: float64(8)
# memory usage: 17.6 KB

# %%
initial_data['Adj Close'].tail()
# Out:
#                   AAPL         AMZN          FB         GOOG        MSFT  \
# Date
# 2021-11-01  148.742920  3318.110107  329.980011  2875.479980  329.369995
# 2021-11-02  149.801376  3312.750000  328.079987  2917.260010  333.130005
# 2021-11-03  151.269241  3384.000000  331.619995  2935.800049  334.000000
# 2021-11-04  150.740005  3477.000000  335.850006  2973.659912  336.440002
# 2021-11-05  151.279999  3518.989990  341.130005  2984.820068  336.059998
#
#                    SPY         TSLA       ^VIX
# Date
# 2021-11-01  460.040009  1208.589966  16.410000
# 2021-11-02  461.899994  1172.000000  16.030001
# 2021-11-03  464.720001  1213.859985  15.100000
# 2021-11-04  466.910004  1229.910034  15.440000
# 2021-11-05  468.529999  1222.089966  16.480000

# %%
data.head()
# Out:
#                   AAPL         AMZN          FB         GOOG        MSFT  \
# Date
# 2020-11-09  115.607307  3143.739990  278.769989  1763.000000  216.404266
# 2020-11-10  115.259445  3035.020020  272.429993  1740.390015  209.091370
# 2020-11-11  118.757874  3137.389893  276.480011  1752.709961  214.581009
# 2020-11-12  118.479607  3110.280029  275.079987  1749.839966  213.481110
# 2020-11-13  118.529297  3128.810059  276.950012  1777.020020  214.541367
#
#                    SPY        TSLA       ^VIX
# Date
# 2020-11-09  349.634827  421.260010  25.750000
# 2020-11-10  349.122101  410.359985  24.799999
# 2020-11-11  351.715546  417.130005  23.450001
# 2020-11-12  348.303589  411.760010  25.350000
# 2020-11-13  353.125702  408.500000  23.100000

# %%
data.tail()
# Out:
#                   AAPL         AMZN          FB         GOOG        MSFT  \
# Date
# 2021-11-01  148.742920  3318.110107  329.980011  2875.479980  329.369995
# 2021-11-02  149.801376  3312.750000  328.079987  2917.260010  333.130005
# 2021-11-03  151.269241  3384.000000  331.619995  2935.800049  334.000000
# 2021-11-04  150.740005  3477.000000  335.850006  2973.659912  336.440002
# 2021-11-05  151.279999  3518.989990  341.130005  2984.820068  336.059998
#
#                    SPY         TSLA       ^VIX
# Date
# 2021-11-01  460.040009  1208.589966  16.410000
# 2021-11-02  461.899994  1172.000000  16.030001
# 2021-11-03  464.720001  1213.859985  15.100000
# 2021-11-04  466.910004  1229.910034  15.440000
# 2021-11-05  468.529999  1222.089966  16.480000

# %%
data.plot(figsize=(10, 12), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002156E354668>,
# ...
#       dtype=object)

# %%
data.plot(figsize=(10, 12), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002156EE75E80>,
# ...
#       dtype=object)

# %%
data.describe().round(2)
# Out:
#          AAPL     AMZN      FB     GOOG    MSFT     SPY     TSLA    ^VIX
# count  251.00   251.00  251.00   251.00  251.00  251.00   251.00  251.00
# mean   134.13  3298.31  312.60  2337.69  257.52  408.70   708.80   19.97
# std     10.87   157.96   37.61   400.24   33.09   31.64   129.54    3.47
# min    113.15  2951.95  245.64  1723.50  208.74  348.30   408.09   15.01
# 25%    125.37  3185.95  275.31  2036.54  231.37  380.34   640.09   17.10
# 50%    132.72  3291.61  315.46  2354.25  251.24  414.57   688.72   19.46
# 75%    145.12  3395.96  342.45  2731.10  286.49  435.94   758.24   22.19
# max    156.46  3731.41  382.18  2984.82  336.44  468.53  1229.91   37.21

# %%
data.diff().head()
# Out:
#                 AAPL        AMZN        FB       GOOG      MSFT       SPY  \
# Date
# 2020-11-09       NaN         NaN       NaN        NaN       NaN       NaN
# 2020-11-10 -0.347862 -108.719971 -6.339996 -22.609985 -7.312897 -0.512726
# 2020-11-11  3.498428  102.369873  4.050018  12.319946  5.489639  2.593445
# 2020-11-12 -0.278267  -27.109863 -1.400024  -2.869995 -1.099899 -3.411957
# 2020-11-13  0.049690   18.530029  1.870026  27.180054  1.060257  4.822113
#
#                  TSLA      ^VIX
# Date
# 2020-11-09        NaN       NaN
# 2020-11-10 -10.900024 -0.950001
# 2020-11-11   6.770020 -1.349998
# 2020-11-12  -5.369995  1.900000
# 2020-11-13  -3.260010 -2.250000

# %%
data.diff().describe().round(2)
# Out:
#          AAPL    AMZN      FB    GOOG    MSFT     SPY    TSLA    ^VIX
# count  250.00  250.00  250.00  250.00  250.00  250.00  250.00  250.00
# mean     0.14    1.50    0.25    4.89    0.48    0.48    3.20   -0.04
# std      2.05   49.12    5.53   33.38    3.23    3.09   24.33    1.89
# min     -5.10 -272.33  -17.27 -106.34  -10.65   -9.35  -68.83   -7.00
# 25%     -1.03  -25.40   -3.28  -12.64   -1.34   -1.22   -9.49   -0.93
# 50%      0.17    4.28    0.12    5.90    0.24    0.64    1.93   -0.24
# 75%      1.48   32.13    4.05   20.43    2.71    2.38   15.01    0.74
# max      6.50  164.76   22.41  142.56   13.06    9.13  115.18   14.19

# %%
data.pct_change().round(4).head()
# Out:
#               AAPL    AMZN      FB    GOOG    MSFT     SPY    TSLA    ^VIX
# Date
# 2020-11-09     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2020-11-10 -0.0030 -0.0346 -0.0227 -0.0128 -0.0338 -0.0015 -0.0259 -0.0369
# 2020-11-11  0.0304  0.0337  0.0149  0.0071  0.0263  0.0074  0.0165 -0.0544
# 2020-11-12 -0.0023 -0.0086 -0.0051 -0.0016 -0.0051 -0.0097 -0.0129  0.0810
# 2020-11-13  0.0004  0.0060  0.0068  0.0155  0.0050  0.0138 -0.0079 -0.0888

# %%
data.pct_change().mean().plot(kind='bar', figsize=(10, 6));

# %%
rets = np.log(data / data.shift(1))
rets.head().round(4)
# Out:
#               AAPL    AMZN      FB    GOOG    MSFT     SPY    TSLA    ^VIX
# Date
# 2020-11-09     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2020-11-10 -0.0030 -0.0352 -0.0230 -0.0129 -0.0344 -0.0015 -0.0262 -0.0376
# 2020-11-11  0.0299  0.0332  0.0148  0.0071  0.0259  0.0074  0.0164 -0.0560
# 2020-11-12 -0.0023 -0.0087 -0.0051 -0.0016 -0.0051 -0.0097 -0.0130  0.0779
# 2020-11-13  0.0004  0.0059  0.0068  0.0154  0.0050  0.0137 -0.0079 -0.0929

# %%
rets.cumsum().apply(np.exp).plot(figsize=(10, 6));

# %%
data.resample('1w', label='right').last().head()
# Out:
#                   AAPL         AMZN          FB         GOOG        MSFT  \
# Date
# 2020-11-15  118.529297  3128.810059  276.950012  1777.020020  214.541367
# 2020-11-22  116.621048  3099.399902  269.700012  1742.189941  209.022812
# 2020-11-29  115.875641  3195.340088  277.809998  1793.189941  213.831360
# 2020-12-06  121.500977  3162.580078  279.700012  1827.989990  212.967026
# 2020-12-13  121.659988  3116.419922  273.549988  1781.770020  211.874161
#
#                    SPY        TSLA       ^VIX
# Date
# 2020-11-15  353.125702  408.500000  23.100000
# 2020-11-22  350.394135  489.609985  23.700001
# 2020-11-29  358.618317  585.760010  20.840000
# 2020-12-06  364.712433  599.039978  20.790001
# 2020-12-13  361.211792  609.989990  23.309999

# %%
data.resample('1m', label='right').last().head()
# Out:
#                   AAPL         AMZN          FB         GOOG        MSFT  \
# Date
# 2020-11-30  118.320580  3168.040039  276.970001  1760.739990  212.678909
# 2020-12-31  131.877014  3256.929932  273.160004  1751.880005  220.974640
# 2021-01-31  131.151474  3206.199951  258.329987  1835.739990  230.452652
# 2021-02-28  120.697136  3092.929932  257.619995  2036.859985  231.401657
# 2021-03-31  121.583000  3094.080078  294.529999  2068.629883  234.777374
#
#                    SPY        TSLA       ^VIX
# Date
# 2020-11-30  357.030701  567.599976  20.570000
# 2020-12-31  370.258057  705.669983  22.750000
# 2021-01-31  366.484985  793.530029  33.090000
# 2021-02-28  376.675262  675.500000  27.950001
# 2021-03-31  393.776062  667.929993  19.400000

# %%
rets.cumsum().apply(np.exp). resample('1w', label='right').last().plot(figsize=(10, 6))

# %%
rets.cumsum().apply(np.exp). resample('1m', label='right').last().plot(figsize=(10, 6))

# %%
data.resample('1w', label='right').last().head(12)
# Out:
#                   AAPL         AMZN          FB         GOOG        MSFT  \
# Date
# 2020-11-15  118.529297  3128.810059  276.950012  1777.020020  214.541367
# 2020-11-22  116.621048  3099.399902  269.700012  1742.189941  209.022812
# 2020-11-29  115.875641  3195.340088  277.809998  1793.189941  213.831360
# 2020-12-06  121.500977  3162.580078  279.700012  1827.989990  212.967026
# 2020-12-13  121.659988  3116.419922  273.549988  1781.770020  211.874161
# 2020-12-20  125.883957  3201.649902  276.399994  1731.010010  217.169525
# 2020-12-27  131.161407  3172.689941  267.399994  1738.849976  221.302490
# 2021-01-03  131.877014  3256.929932  273.160004  1751.880005  220.974640
# 2021-01-10  131.240921  3182.699951  267.570007  1807.209961  218.192841
# 2021-01-17  126.361008  3104.250000  251.360001  1736.189941  211.268127
# 2021-01-24  138.217911  3292.229980  274.500000  1901.050049  224.481689
# 2021-01-31  131.151474  3206.199951  258.329987  1835.739990  230.452652
#
# ...

# %%
data.resample('1w', label='right').last().head(3)
# Out:
#                   AAPL         AMZN          FB         GOOG        MSFT  \
# Date
# 2020-11-15  118.529297  3128.810059  276.950012  1777.020020  214.541367
# 2020-11-22  116.621048  3099.399902  269.700012  1742.189941  209.022812
# 2020-11-29  115.875641  3195.340088  277.809998  1793.189941  213.831360
#
#                    SPY        TSLA       ^VIX
# Date
# 2020-11-15  353.125702  408.500000  23.100000
# 2020-11-22  350.394135  489.609985  23.700001
# 2020-11-29  358.618317  585.760010  20.840000

# %%
sym = 'TSLA'
TSLA_data = pd.DataFrame(data[sym]).dropna()
TSLA_data.tail()
# Out:
#                    TSLA
# Date
# 2021-11-01  1208.589966
# 2021-11-02  1172.000000
# 2021-11-03  1213.859985
# 2021-11-04  1229.910034
# 2021-11-05  1222.089966

# %%
window = 10
TSLA_data['min'] = data[sym].rolling(window=window).min()
TSLA_data['mean'] = data[sym].rolling(window=window).mean()
TSLA_data['std'] = data[sym].rolling(window=window).std()
TSLA_data['median'] = data[sym].rolling(window=window).median()
TSLA_data['max'] = data[sym].rolling(window=window).max()
TSLA_data['ewma'] = data[sym].ewm(halflife=0.5, min_periods=window).mean()
TSLA_data.dropna().head()
# Out:
#                   TSLA         min        mean        std      median  \
# Date
# 2020-11-20  489.609985  408.089996  439.422998  37.578637  419.195007
# 2020-11-23  521.849976  408.089996  449.481995  44.921987  429.369995
# 2020-11-24  555.380005  408.089996  463.983997  53.481711  464.125000
# 2020-11-25  574.000000  408.089996  479.670996  60.727118  488.125000
# 2020-11-27  585.760010  408.089996  497.070996  63.949131  494.439987
#
#                    max        ewma
# Date
# 2020-11-20  499.269989  490.402609
# 2020-11-23  521.849976  513.988140
# 2020-11-24  555.380005  545.032040
# 2020-11-25  574.000000  566.758010
# 2020-11-27  585.760010  581.009510

# %%
ax = AAPL_data[['min', 'mean', 'max']].iloc[-200:].plot(figsize=(10, 6), style=['g--', 'r--', 'g--'], lw=0.8)
data[sym].iloc[-200:].plot(ax=ax, lw=2.0);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-7b3ce62342bb> in <module>
#       1
# ----> 2 ax = AAPL_data[['min', 'mean', 'max']].iloc[-200:].plot(figsize=(10, 6), style=['g--', 'r--', 'g--'], lw=0.8)
#       3 data[sym].iloc[-200:].plot(ax=ax, lw=2.0);
#
# NameError: name 'AAPL_data' is not defined

# %%
ax = TSLA_data[['min', 'mean', 'max']].iloc[-200:].plot(figsize=(10, 6), style=['g--', 'r--', 'b--'], lw=0.8)
data[sym].iloc[-200:].plot(ax=ax, lw=2.0);

# %%
TSLA_data['SMA1'] = data[sym].rolling(window=20).mean()
TSLA_data['SMA2'] = data[sym].rolling(window=60).mean()
TSLA_data[[sym, 'SMA1', 'SMA2']].tail()
# Out:
#                    TSLA        SMA1        SMA2
# Date
# 2021-11-01  1208.589966  904.858499  790.970164
# 2021-11-02  1172.000000  924.428998  798.607497
# 2021-11-03  1213.859985  945.984497  807.005330
# 2021-11-04  1229.910034  967.799500  815.706831
# 2021-11-05  1222.089966  989.629498  824.037497

# %%
TSLA_data[[sym, 'SMA1', 'SMA2']].head()
# Out:
#                   TSLA  SMA1  SMA2
# Date
# 2020-11-09  421.260010   NaN   NaN
# 2020-11-10  410.359985   NaN   NaN
# 2020-11-11  417.130005   NaN   NaN
# 2020-11-12  411.760010   NaN   NaN
# 2020-11-13  408.500000   NaN   NaN

# %%
TSLA_data[[sym, 'SMA1', 'SMA2']].plot(figsize=(10, 6))

# %%
TSLA_data.dropna(inplace=True)
TSLA_data['positions'] = np.where(TSLA_data['SMA1'] > TSLA_data['SMA2'],1,-1)
ax = TSLA_data[[sym, 'SMA1', 'SMA2', 'positions']].plot(figsize=(10, 6),secondary_y='positions')
ax.get_legend().set_bbox_to_anchor((0.25, 0.85))

# %% [markdown]
# Corr_data = data[['SPY', '^VIX']].dropna()
# Corr_data.tail()

# %%
Corr_data = data[['SPY', '^VIX']].dropna()
Corr_data.tail()
# Out:
#                    SPY       ^VIX
# Date
# 2021-11-01  460.040009  16.410000
# 2021-11-02  461.899994  16.030001
# 2021-11-03  464.720001  15.100000
# 2021-11-04  466.910004  15.440000
# 2021-11-05  468.529999  16.480000

# %%
Corr_data.plot(subplots=True, figsize=(10, 6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002156FACBFD0>,
# ...
#       dtype=object)

# %%
Corr_data.loc['2020-01-01':].plot(secondary_y='^VIX', figsize=(10, 6));

# %%
sprets = np.log(Corr_data / Corr_data.shift(1))
sprets.head()
# Out:
#                  SPY      ^VIX
# Date
# 2020-11-09       NaN       NaN
# 2020-11-10 -0.001468 -0.037591
# 2020-11-11  0.007401 -0.055973
# 2020-11-12 -0.009748  0.077908
# 2020-11-13  0.013750 -0.092946

# %%
sprets.dropna(inplace=True)
sprets.plot(subplots=True, figsize=(10, 6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002156FDE8320>,
# ...
#       dtype=object)

# %%
pd.plotting.scatter_matrix(sprets, alpha=0.2, diagonal='hist', hist_kwds={'bins': 35}, figsize=(10, 6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002156FD35F60>,
# ...
#       dtype=object)

# %%
reg = np.polyfit(sprets['SPY'], sprets['^VIX'], deg=1)
ax = sprets.plot(kind='scatter', x='SPY', y='^VIX', figsize=(10, 6))
ax.plot(sprets['SPY'], np.polyval(reg, sprets['SPY']), 'r', lw=2);

# %%
sprets.corr()
# Out:
#            SPY      ^VIX
# SPY   1.000000 -0.828792
# ^VIX -0.828792  1.000000

# %%
ax = sprets['SPY'].rolling(window=20).corr(sprets['^VIX']).plot(figsize=(10, 6)) 
ax.axhline(sprets.corr().iloc[0, 1], c='r');

# %%
import yfinance as yf
import numpy as np
import pandas as pd

# %%
data = yf.download("AMZN TSLA", start="2020-11-01", end="2021-11-01")
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
data.tail()
# Out:
#               Adj Close                     Close                      High  \
#                    AMZN         TSLA         AMZN         TSLA         AMZN
# Date
# 2021-10-25  3320.370117  1024.859985  3320.370117  1024.859985  3347.800049
# 2021-10-26  3376.070068  1018.429993  3376.070068  1018.429993  3416.120117
# 2021-10-27  3392.489990  1037.859985  3392.489990  1037.859985  3437.000000
# 2021-10-28  3446.570068  1077.040039  3446.570068  1077.040039  3479.000000
# 2021-10-29  3372.429932  1114.000000  3372.429932  1114.000000  3374.820068
#
#                                  Low                      Open               \
#                    TSLA         AMZN         TSLA         AMZN         TSLA
# Date
# 2021-10-25  1045.020020  3297.699951   944.200012  3335.000000   950.530029
# 2021-10-26  1094.939941  3343.979980  1001.440002  3349.510010  1024.689941
# 2021-10-27  1070.880005  3371.449951  1030.780029  3388.000000  1039.660034
# ...

# %%
ADJ =  data['Adj Close']
ADJ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2020-11-02 to 2021-10-29
# Data columns (total 2 columns):
# AMZN    251 non-null float64
# TSLA    251 non-null float64
# dtypes: float64(2)
# memory usage: 5.9 KB

# %%
ADJ.plot(figsize=(10, 12), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000021570EA64A8>,
# ...
#       dtype=object)

# %%
ADJ.describe().round(2)
# Out:
#           AMZN     TSLA
# count   251.00   251.00
# mean   3293.99   693.13
# std     158.71   114.70
# min    2951.95   400.51
# 25%    3183.89   629.65
# 50%    3285.85   684.90
# 75%    3385.18   753.76
# max    3731.41  1114.00

# %%
rets = np.log(ADJ / ADJ.shift(1))
rets.head().round(4)
# Out:
#               AMZN    TSLA
# Date
# 2020-11-02     NaN     NaN
# 2020-11-03  0.0145  0.0568
# 2020-11-04  0.0613 -0.0069
# 2020-11-05  0.0246  0.0398
# 2020-11-06 -0.0032 -0.0188

# %%
rets.cumsum().apply(np.exp).plot(figsize=(10, 6));

# %%
sym = 'AMZN'
AMZN_data = pd.DataFrame(ADJ[sym]).dropna()
AMZN_data.tail()
# Out:
#                    AMZN
# Date
# 2021-10-25  3320.370117
# 2021-10-26  3376.070068
# 2021-10-27  3392.489990
# 2021-10-28  3446.570068
# 2021-10-29  3372.429932

# %%
AMZN_data['SMA1'] = ADJ[sym].rolling(window=10).mean()
AMZN_data['SMA2'] = ADJ[sym].rolling(window=60).mean()
AMZN_data[[sym, 'SMA1', 'SMA2']].tail()
# Out:
#                    AMZN         SMA1         SMA2
# Date
# 2021-10-25  3320.370117  3363.737036  3354.763342
# 2021-10-26  3376.070068  3376.611035  3355.506510
# 2021-10-27  3392.489990  3387.432031  3355.944010
# 2021-10-28  3446.570068  3402.103027  3357.474845
# 2021-10-29  3372.429932  3398.444019  3357.415511

# %%
AMZN_data.dropna(inplace=True)
AMZN_data['positions'] = np.where(AMZN_data['SMA1'] > AMZN_data['SMA2'],1,-1)
ax = AMZN_data[[sym, 'SMA1', 'SMA2', 'positions']].plot(figsize=(10, 6),secondary_y='positions')
ax.get_legend().set_bbox_to_anchor((0.25, 0.85))

# %%
rets.dropna(inplace=True)
rets.plot(subplots=True, figsize=(10, 6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000021571239828>,
# ...
#       dtype=object)

# %%
pd.plotting.scatter_matrix(rets, alpha=0.2, diagonal='hist', hist_kwds={'bins': 35}, figsize=(10, 6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000215712C25F8>,
# ...
#       dtype=object)

# %%
reg = np.polyfit(rets['AMZN'], rets['TSLA'], deg=1)
ax = rets.plot(kind='scatter', x='AMZN', y='TSLA', figsize=(10, 6))
ax.plot(rets['AMZN'], np.polyval(reg, rets['AMZN']), 'r', lw=2);

# %%
rets.corr()
# Out:
#           AMZN      TSLA
# AMZN  1.000000  0.331862
# TSLA  0.331862  1.000000

# %%
ax = rets['AMZN'].rolling(window=20).corr(rets['TSLA']).plot(figsize=(10, 6)) 
ax.axhline(rets.corr().iloc[0, 1], c='r');
